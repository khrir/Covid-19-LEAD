# %% [markdown]
# ## Dados das cidades alagoanas no ano de 2021

# %%
import pandas as pd
df = pd.read_csv('caso_full_al.csv')
df.head()
# Out:
#      city  city_ibge_code        date  epidemiological_week  \
# 0  Maceió       2704302.0  2020-03-08                202011
# 1  Maceió       2704302.0  2020-03-09                202011
# 2  Maceió       2704302.0  2020-03-10                202011
# 3  Maceió       2704302.0  2020-03-11                202011
# 4  Maceió       2704302.0  2020-03-12                202011
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0             1025360.0                  1018948.0    False        False
# 1             1025360.0                  1018948.0    False        False
# 2             1025360.0                  1018948.0    False        False
# 3             1025360.0                  1018948.0    False         True
# 4             1025360.0                  1018948.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                         1                                        0.09753
# ...

# %%
data_inicial = "2020-12-01"
data_final = "2021-12-01"
df_filtered = df.loc[(df['date'] >= data_inicial) & (df['date'] < data_final)]
# df_filtered.to_csv('dados_full_cidades_2021.csv')
df_filtered.head()
# Out:
#                          city  city_ibge_code        date  \
# 21724                  Anadia       2700201.0  2020-12-01
# 21725               Arapiraca       2700300.0  2020-12-01
# 21726                 Atalaia       2700409.0  2020-12-01
# 21727  Barra de Santo Antônio       2700508.0  2020-12-01
# 21728     Barra de São Miguel       2700607.0  2020-12-01
#
#        epidemiological_week  estimated_population  estimated_population_2019  \
# 21724                202049               17526.0                    17545.0
# 21725                202049              233047.0                   231747.0
# 21726                202049               47365.0                    47185.0
# 21727                202049               16068.0                    15932.0
# 21728                202049                8378.0                     8322.0
#
#        is_last  is_repeated  last_available_confirmed  \
# 21724    False        False                       513
# ...

# %% [markdown]
# ### Testes nos clusters

# %% [markdown]
# ## Dados do estado de Alagoas no ano de 2021

# %%
df_al = pd.read_csv('covid19-full.csv')
df_al.head()
# Out:
#    epidemiological_week        date  order_for_place state  city  \
# 0                202213  2022-03-27              750    AL   NaN
# 1                202212  2022-03-26              749    AL   NaN
# 2                202212  2022-03-25              748    AL   NaN
# 3                202212  2022-03-24              747    AL   NaN
# 4                202212  2022-03-23              746    AL   NaN
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0              27      state                    295972
# 1              27      state                    295972
# 2              27      state                    295916
# 3              27      state                    295714
# 4              27      state                    295519
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                     8830.91758              0
# 1                                     8830.91758             56
# ...

# %%
df_filtered_al = df_al.loc[(df_al['date'] >= data_inicial) & (df_al['date'] < data_final)]
# df_filtered_al.to_csv('dados_full_alagoas_2021.csv')
df_filtered_al.head()
# Out:
#      epidemiological_week        date  order_for_place state  city  \
# 117                202148  2021-11-30              633    AL   NaN
# 118                202148  2021-11-29              632    AL   NaN
# 119                202148  2021-11-28              631    AL   NaN
# 120                202147  2021-11-27              630    AL   NaN
# 121                202147  2021-11-26              629    AL   NaN
#
#      city_ibge_code place_type  last_available_confirmed  \
# 117              27      state                    241490
# 118              27      state                    241471
# 119              27      state                    241432
# 120              27      state                    241409
# 121              27      state                    241394
#
#      last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 117                                     7205.33796             19
# 118                                     7204.77106             39
# ...

# %% [markdown]
# ### Teste de série temporal no estado de Alagoas

# %%
from statsmodels.tsa.stattools import adfuller

df_filtered_al = df_filtered_al[['date', 'new_deaths']]
df_filtered_al.loc[:,'date'] = pd.to_datetime(df_filtered_al.loc[:,"date"]).copy()
df_filtered_al.set_index('date', inplace=True)

adfuller(df_filtered_al)
# Out:
# (-0.9178381431050315,
#  0.7820413171714241,
#  1,
#  363,
#  {'1%': -3.448493650810824,
#   '5%': -2.8695352280356556,
#   '10%': -2.5710293341377715},
#  871.807498546134)
